# %%
from alphagenome.data import genome
from alphagenome.models import dna_client, variant_scorers
import pandas as pd
from tqdm import tqdm
from dotenv import load_dotenv
import os
import pandas as pd

load_dotenv()
ALPHAGENOME_KEY=os.getenv('ALPHAGENOME_KEY')
save_predictions = True

# %%
# Load tsv file which only has variants above -log10p of 7.
df = pd.read_csv('gwas1_log10p_gt_7.tsv', sep='\t')
df.CHROM = 'chr' + df.CHROM.astype(str)
df
# Out:
#      CHROM    GENPOS               ID ALLELE0 ALLELE1    A1FREQ  A1FREQ_CASES  \
# 0     chr6  26205065   6:26205065:G:A       G       A  0.468846      0.490179
# 1     chr6  26210918   6:26210918:G:T       G       T  0.273908      0.289524
# 2     chr6  26214245   6:26214245:T:C       T       C  0.474028      0.495378
# 3     chr6  26225804   6:26225804:C:G       C       G  0.284913      0.301078
# 4     chr6  26233159   6:26233159:A:G       A       G  0.274226      0.291707
# ..     ...       ...              ...     ...     ...       ...           ...
# 337  chr20  49274119  20:49274119:A:G       A       G  0.391124      0.373098
# 338  chr20  49275101  20:49275101:C:T       C       T  0.390888      0.372745
# 339  chr20  49278429  20:49278429:G:A       G       A  0.389233      0.371333
# 340  chr20  49291253  20:49291253:A:G       A       G  0.390944      0.372713
# 341  chr20  49297643  20:49297643:G:C       G       C  0.391015      0.372906
#
#      A1FREQ_CONTROLS       N  N_CASES  N_CONTROLS TEST      BETA        SE  \
# 0           0.496948  275488    15579      259909  ADD  0.066559  0.012493
# 1           0.290326  275488    15579      259909  ADD  0.075221  0.013859
# 2           0.502440  275488    15579      259909  ADD  0.066576  0.012478
# 3           0.301990  275488    15579      259909  ADD  0.073885  0.013698
# 4           0.290663  275488    15579      259909  ADD  0.079009  0.013844
# ..               ...     ...      ...         ...  ...       ...       ...
# 337         0.414567  275488    15579      259909  ADD -0.077317  0.013166
# 338         0.414317  275488    15579      259909  ADD -0.077830  0.013168
# 339         0.412563  275488    15579      259909  ADD -0.077548  0.013177
# 340         0.414377  275488    15579      259909  ADD -0.077937  0.013169
# 341         0.414452  275488    15579      259909  ADD -0.077592  0.013168
#
#        CHISQ   LOG10P  EXTRA
# 0    28.3848  7.00242    NaN
# 1    29.4583  7.24311    NaN
# 2    28.4681  7.02110    NaN
# 3    29.0931  7.16125    NaN
# 4    32.5706  7.93952    NaN
# ..       ...      ...    ...
# 337  34.4866  8.36734    NaN
# 338  34.9351  8.46739    NaN
# 339  34.6343  8.40029    NaN
# 340  35.0244  8.48732    NaN
# 341  34.7212  8.41968    NaN
#
# [342 rows x 17 columns]

# %%
dna_model = dna_client.create(ALPHAGENOME_KEY)

# %%
# Sequence length and scorer selection

sequence_length = '1MB'  # "16KB", "100KB", "500KB", "1MB"
sequence_length = dna_client.SUPPORTED_SEQUENCE_LENGTHS[
    f'SEQUENCE_LENGTH_{sequence_length}'
]

scorer_selections = {
    'rna_seq': True,
    'cage': False,
    'procap': False,
    'atac': False,
    'dnase': False,
    'chip_histone': False,
    'chip_tf': False,
    'polyadenylation': False,
    'splice_sites': False,
    'splice_site_usage': False,
    'splice_junctions': False,
}

all_scorers = variant_scorers.RECOMMENDED_VARIANT_SCORERS
selected_scorers = [
    all_scorers[key]
    for key in all_scorers
    if scorer_selections.get(key.lower(), False)
]

# %%
results = []
for i, row in tqdm(df.iterrows(), total=len(df)):
  variant = genome.Variant(
      chromosome=str(row.CHROM),
      position=int(row.GENPOS),
      reference_bases=row.ALLELE0,
      alternate_bases=row.ALLELE1,
      name=row.ID,
  )
  interval = variant.reference_interval.resize(sequence_length)

  variant_scores = dna_model.score_variant(
      interval=interval,
      variant=variant,
      variant_scorers=selected_scorers,
      organism=dna_client.Organism.HOMO_SAPIENS,
  )
  results.append(variant_scores)
# Out:
# 100%|█████████████████████████████████████████| 342/342 [06:31<00:00,  1.14s/it]

# %%
df_scores = variant_scorers.tidy_scores(results)
df_scores['abs_quantile_score'] = abs(df_scores['quantile_score'])
df_scores = df_scores.sort_values('abs_quantile_score', ascending=False)

df_scores.to_csv('variant-scores_rnaseq_decodeme_significant_all-tissues.csv.gz', index=False, compression='gzip')

df_scores
# Out:
#                      variant_id            scored_interval          gene_id  \
# 2095528     chr20:48905549:CT>C  chr20:48381261-49429837:.  ENSG00000230758
# 2609855  chr20:49012496:T>TTTTG  chr20:48488208-49536784:.  ENSG00000226284
# 3102464   chr20:49105400:TTTG>T  chr20:48581113-49629689:.  ENSG00000124212
# 3102480   chr20:49105400:TTTG>T  chr20:48581113-49629689:.  ENSG00000124212
# 3102472   chr20:49105400:TTTG>T  chr20:48581113-49629689:.  ENSG00000124212
# ...                         ...                        ...              ...
# 87802         chr6:26214245:T>C   chr6:25689957-26738533:.  ENSG00000287050
# 973938        chr6:26306054:T>C   chr6:25781766-26830342:.  ENSG00000196866
# 1208546       chr6:26325805:C>T   chr6:25801517-26850093:.  ENSG00000287050
# 2117894      chr20:48906783:C>T  chr20:48382495-49431071:.  ENSG00000236874
# 3382849      chr20:49144319:A>G  chr20:48620031-49668607:.  ENSG00000283529
#
#                gene_name                           gene_type gene_strand  \
# 2095528         SNAP23P1                processed_pseudogene           -
# 2609855          ARPC3P1                processed_pseudogene           +
# 3102464            PTGIS                      protein_coding           -
# 3102480            PTGIS                      protein_coding           -
# 3102472            PTGIS                      protein_coding           -
# ...                  ...                                 ...         ...
# 87802    ENSG00000287050                              lncRNA           -
# 973938             H2AC7                      protein_coding           -
# 1208546  ENSG00000287050                              lncRNA           -
# 2117894  ENSG00000236874                              lncRNA           -
# 3382849  ENSG00000283529  transcribed_unprocessed_pseudogene           +
#
#         junction_Start junction_End output_type  \
# 2095528           None         None     RNA_SEQ
# 2609855           None         None     RNA_SEQ
# 3102464           None         None     RNA_SEQ
# 3102480           None         None     RNA_SEQ
# 3102472           None         None     RNA_SEQ
# ...                ...          ...         ...
# 87802             None         None     RNA_SEQ
# 973938            None         None     RNA_SEQ
# 1208546           None         None     RNA_SEQ
# 2117894           None         None     RNA_SEQ
# 3382849           None         None     RNA_SEQ
#
#                                       variant_scorer  ...  \
# 2095528  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 2609855  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 3102464  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 3102480  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 3102472  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# ...                                              ...  ...
# 87802    GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 973938   GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1208546  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 2117894  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 3382849  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
#
#                                             biosample_name  \
# 2095528                                   endothelial cell
# 2609855                                               MG63
# 3102464                endothelial cell of coronary artery
# 3102480  dermis microvascular lymphatic vessel endothel...
# 3102472             bladder microvascular endothelial cell
# ...                                                    ...
# 87802                                     body of pancreas
# 973938                        bronchial smooth muscle cell
# 1208546                                       Ammon's horn
# 2117894                                    urinary bladder
# 3382849                    CD8-positive, alpha-beta T cell
#
#                         biosample_type biosample_life_stage  \
# 2095528  in_vitro_differentiated_cells                adult
# 2609855                      cell_line                child
# 3102464                   primary_cell                adult
# 3102480                   primary_cell                adult
# 3102472                   primary_cell                adult
# ...                                ...                  ...
# 87802                           tissue                adult
# 973938                    primary_cell                adult
# 1208546                         tissue                adult
# 2117894                         tissue            embryonic
# 3382849                   primary_cell                adult
#
#                gtex_tissue data_source endedness genetically_modified  \
# 2095528                         encode    single                False
# 2609855                         encode    paired                False
# 3102464                         encode    paired                False
# 3102480                         encode    paired                False
# 3102472                         encode    paired                False
# ...                    ...         ...       ...                  ...
# 87802                           encode    paired                False
# 973938                          encode    paired                False
# 1208546  Brain_Hippocampus        gtex    paired                False
# 2117894                         encode    paired                False
# 3382849                         encode    paired                False
#
#             raw_score quantile_score abs_quantile_score
# 2095528  1.833034e-01   9.999800e-01       9.999800e-01
# 2609855  1.973138e-01   9.999800e-01       9.999800e-01
# 3102464 -3.197962e-01  -9.999800e-01       9.999800e-01
# 3102480 -4.071872e-01  -9.999800e-01       9.999800e-01
# 3102472 -4.263840e-01  -9.999800e-01       9.999800e-01
# ...               ...            ...                ...
# 87802    0.000000e+00   1.137757e-12       1.137757e-12
# 973938  -2.384186e-07   1.137757e-12       1.137757e-12
# 1208546 -4.768372e-07   1.137757e-12       1.137757e-12
# 2117894 -4.768372e-07   1.137757e-12       1.137757e-12
# 3382849 -2.861023e-06   1.137757e-12       1.137757e-12
#
# [3800412 rows x 24 columns]

# %%
ontologies = ['UBERON:0000955']
gene_types = ['protein_coding']
df_scores_subset = df_scores[df_scores['ontology_curie'].isin(ontologies) & df_scores['gene_type'].isin(gene_types)]

if save_predictions:
  df_scores_subset.to_csv('variant-scores_rnaseq_decodeme_significant_brain_protein-coding.csv.gz', index=False, compression='gzip')

df_scores_subset
# Out:
#                       variant_id            scored_interval          gene_id  \
# 3146736   chr20:49109692:C>CTTTT  chr20:48585404-49633980:.  ENSG00000124212
# 1284171       chr6:26328470:A>AT   chr6:25804182-26852758:.  ENSG00000124557
# 3283438  chr20:49132759:CCAAAA>C  chr20:48608473-49657049:.  ENSG00000124228
# 3103176    chr20:49105400:TTTG>T  chr20:48581113-49629689:.  ENSG00000124212
# 3460368      chr20:49153402:T>TA  chr20:48629114-49677690:.  ENSG00000124212
# ...                          ...                        ...              ...
# 3016056       chr20:49100868:T>C  chr20:48576580-49625156:.  ENSG00000124212
# 2494273       chr20:48955014:C>G  chr20:48430726-49479302:.  ENSG00000124201
# 1040886        chr6:26317156:C>T   chr6:25792868-26841444:.  ENSG00000124564
# 882492         chr6:26302950:T>G   chr6:25778662-26827238:.  ENSG00000181315
# 2023407       chr17:52220547:A>G  chr17:51696259-52744835:.  ENSG00000154975
#
#         gene_name       gene_type gene_strand junction_Start junction_End  \
# 3146736     PTGIS  protein_coding           -           None         None
# 1284171    BTN1A1  protein_coding           +           None         None
# 3283438     DDX27  protein_coding           +           None         None
# 3103176     PTGIS  protein_coding           -           None         None
# 3460368     PTGIS  protein_coding           -           None         None
# ...           ...             ...         ...            ...          ...
# 3016056     PTGIS  protein_coding           -           None         None
# 2494273     ZNFX1  protein_coding           -           None         None
# 1040886   SLC17A3  protein_coding           -           None         None
# 882492     ZNF322  protein_coding           -           None         None
# 2023407      CA10  protein_coding           -           None         None
#
#         output_type                               variant_scorer  ...  \
# 3146736     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1284171     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 3283438     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 3103176     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 3460368     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# ...             ...                                          ...  ...
# 3016056     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 2494273     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 1040886     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 882492      RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 2023407     RNA_SEQ  GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
#
#         biosample_name biosample_type biosample_life_stage gtex_tissue  \
# 3146736          brain         tissue                adult
# 1284171          brain         tissue                adult
# 3283438          brain         tissue                adult
# 3103176          brain         tissue                adult
# 3460368          brain         tissue                adult
# ...                ...            ...                  ...         ...
# 3016056          brain         tissue                adult
# 2494273          brain         tissue                adult
# 1040886          brain         tissue                adult
# 882492           brain         tissue                adult
# 2023407          brain         tissue                adult
#
#         data_source endedness genetically_modified     raw_score  \
# 3146736      encode    paired                False  1.050655e-01
# 1284171      encode    paired                False -9.972215e-02
# 3283438      encode    paired                False  7.458559e-02
# 3103176      encode    paired                False -8.859038e-02
# 3460368      encode    paired                False  7.188678e-02
# ...             ...       ...                  ...           ...
# 3016056      encode    paired                False -2.980232e-06
# 2494273      encode    paired                False -2.801418e-06
# 1040886      encode    paired                False -1.430511e-06
# 882492       encode    paired                False -8.344650e-07
# 2023407      encode    paired                False  0.000000e+00
#
#         quantile_score abs_quantile_score
# 3146736   9.999366e-01       9.999366e-01
# 1284171  -9.999220e-01       9.999220e-01
# 3283438   9.999164e-01       9.999164e-01
# 3103176  -9.998872e-01       9.998872e-01
# 3460368   9.998845e-01       9.998845e-01
# ...                ...                ...
# 3016056  -3.459415e-02       3.459415e-02
# 2494273  -3.459415e-02       3.459415e-02
# 1040886  -2.306788e-02       2.306788e-02
# 882492   -1.153548e-02       1.153548e-02
# 2023407   1.137757e-12       1.137757e-12
#
# [4398 rows x 24 columns]
